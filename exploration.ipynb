# %%
from results import generate_results, get_datasets
import matplotlib.pyplot as plt
import numpy as np

# %%
def get_statistics(v, r, p):
    datasets = ['mean_reward', 'mean_std', 'entropy_bonus']
    for d in datasets:
        mv, mp, mq = get_datasets(v,r, p, data_name=d)
        mv, mp, mq = np.mean(mv[-200:]), np.mean(mp[-200:]), np.mean(mq[-200:])
        print(d.title())
        print(mv, "\t", mp, "\t",  mq , "\t")

# %% [markdown]
# ## Hooper Environment

# %%
p_v = "/Users/jmuneton/Documents/stanford/s_2024/cs234/project/project/experiments/ vanilla_ppo_hopper/agents_none/exp_20240610_142118/data.h5"
p_r = "/Users/jmuneton/Documents/stanford/s_2024/cs234/project/project/experiments/ robust_ppo_sgld_hopper_best/_none/exp_20240610_204038/data.h5"
p_w = "/Users/jmuneton/Documents/stanford/s_2024/cs234/project/project/experiments/ robust_q_ppo_sgld_hopper_best/agents_none/exp_20240610_161030/data.h5"
generate_results(p_v, p_r, p_w, task='Hopper-V4', attack='None')

# %%
get_statistics(p_v, p_r, p_w)
# Out:
# Mean_Reward
# 2031.7886033024724 	 1540.4426703680424 	 2493.916485523663
# Mean_Std
# 0.10730564050376415 	 0.7752762043476105 	 0.4310367020964623
# Entropy_Bonus
# 0.0 	 3.2668639755249025 	 1.682427430152893

# %%
# Random
p_v = "/Users/jmuneton/Documents/stanford/s_2024/cs234/project/project/experiments/ vanilla_ppo_hopper/agents_random/exp_20240610_143711/data.h5"
p_r = "/Users/jmuneton/Documents/stanford/s_2024/cs234/project/project/experiments/ robust_ppo_sgld_hopper_best/_random/exp_20240610_210712/data.h5"
p_w = "/Users/jmuneton/Documents/stanford/s_2024/cs234/project/project/experiments/ robust_q_ppo_sgld_hopper_best/agents_random/exp_20240610_171729/data.h5"
generate_results(p_v, p_r, p_w, task='Hopper-V4', attack='Random')
get_statistics(p_v, p_r, p_w)
# Out:
# Mean_Reward
# 3053.6212629446395 	 1451.358758707137 	 2242.378520608838
# Mean_Std
# 0.11586133897304535 	 0.7579224210977554 	 0.3648803198337555
# Entropy_Bonus
# 0.0 	 3.3687226462364195 	 1.230139865875244

# %% [markdown]
# ### Critic Random

# %%
# Critic
p_v = "/Users/jmuneton/Documents/stanford/s_2024/cs234/project/project/experiments/ vanilla_ppo_hopper/agents_critic/exp_20240610_145327/data.h5"
p_r = "/Users/jmuneton/Documents/stanford/s_2024/cs234/project/project/experiments/ robust_ppo_sgld_hopper_best/_critic/exp_20240610_213351/data.h5"
p_w = "/Users/jmuneton/Documents/stanford/s_2024/cs234/project/project/experiments/ robust_q_ppo_sgld_hopper_best/agents_critic/exp_20240610_183526/data.h5"
generate_results(p_v, p_r, p_w, task='Hopper-V4', attack='Critic')
get_statistics(p_v, p_r, p_w)
# Out:
# Mean_Reward
# 2280.4408317933376 	 1672.7882085189337 	 2330.568950911941
# Mean_Std
# 0.13142836913466455 	 0.7467850655317306 	 0.3965186643600464
# Entropy_Bonus
# 0.0 	 3.223687083721161 	 1.4742071437835693

# %%
## cheetah 

p_v = "/Users/jmuneton/Documents/stanford/s_2024/cs234/project/project/experiments/ vanilla_ppo_halfcheetah/agents_none/exp_20240609_183200/data.h5"
p_r = "/Users/jmuneton/Documents/stanford/s_2024/cs234/project/project/experiments/ robust_ppo_halfcheetah/agents_none/exp_20240609_201658/data.h5"
p_w = "/Users/jmuneton/Documents/stanford/s_2024/cs234/project/project/experiments/ robust_q_ppo_sgld_hopper_best/agents_none/exp_20240610_161030/data.h5"
generate_results(p_v, p_r, p_w, task='HalfCheetah-V4', attack='None')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[9], line 6
#       4 p_r = "/Users/jmuneton/Documents/stanford/s_2024/cs234/project/project/experiments/ robust_ppo_halfcheetah/agents_none/exp_20240609_201658/data.h5"
#       5 p_w = "/Users/jmuneton/Documents/stanford/s_2024/cs234/project/project/experiments/ robust_q_ppo_sgld_hopper_best/agents_none/exp_20240610_161030/data.h5"
# ----> 6 generate_results(p_v, p_r, p_w, task='HalfCheetah-V4', attack='None')
#
# File ~/Documents/stanford/s_2024/cs234/project/project/results.py:156, in generate_results(p_v, p_r, p_w, task, attack)
#     154 def generate_results(p_v, p_r, p_w, task, attack):
# --> 156     build_reward_plot(p_v, p_r, p_w, task, attack)
#     157     build_std_plot(p_v, p_r, p_w, task, attack)
#     158     build_entropy_plot(p_v, p_r, p_w, task, attack)
#
# ...

# %%
## Random
p_v = "/Users/jmuneton/Documents/stanford/s_2024/cs234/project/project/experiments/ vanilla_ppo_halfcheetah/agents_random/exp_20240609_184639/data.h5"
p_r = "/Users/jmuneton/Documents/stanford/s_2024/cs234/project/project/experiments/ robust_ppo_halfcheetah/agents_random/exp_20240609_204146/data.h5"
p_w = "/Users/jmuneton/Documents/stanford/s_2024/cs234/project/project/experiments/ robust_q_ppo_sgld_hopper_best/agents_none/exp_20240610_161030/data.h5"
generate_results(p_v, p_r, p_w, task='HalfCheetah-V4', attack='None')

# %%
#Critic
p_v = "/Users/jmuneton/Documents/stanford/s_2024/cs234/project/project/experiments/ vanilla_ppo_halfcheetah/agents_critic/exp_20240609_190107/data.h5"
p_r = "/Users/jmuneton/Documents/stanford/s_2024/cs234/project/project/experiments/ robust_ppo_halfcheetah/agents_critic/exp_20240609_210651/data.h5"
p_w = "/Users/jmuneton/Documents/stanford/s_2024/cs234/project/project/experiments/ robust_q_ppo_sgld_hopper_best/agents_none/exp_20240610_161030/data.h5"
generate_results(p_v, p_r, p_w, task='HalfCheetah-V4', attack='None')

# %%
vc, pc, qc, epochs = get_datasets()
plot(vc, pc, qc, "critic", epochs)

# %%
def get_data(path, dataset, verbose=False):
    d = {}
    with h5py.File(path, 'r') as f:
        for dataset_name in f.keys():
            if verbose:
                print(dataset_name)
            d[dataset_name] = np.array(f[dataset_name][:])
    return d[dataset]

def get_datasets(vanilla, robust_ppo, robust_q_ppo, data_name):
    v = get_data(vanilla, data_name, verbose=True)
    p =  get_data(robust_ppo, data_name)
    q =  get_data(robust_q_ppo, data_name)
    return v, p, q

# %%
def plot(v, p, q, config, title, x_axis, y_axis, log=False):
    epochs=np.arange(len(v))
    # Creating the figure and subplots
    fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(18, 6))  # 1 row, 3 columns
    title = F'{title.title()} {config.title()}'
    # Plotting data
    ax1.plot(epochs, v, label='Vanilla', color='tab:blue')
    ax1.set_title(title.title())
    ax1.set_xlabel(x_axis.title())
    ax1.set_ylabel(y_axis.title())
    if log:
        ax1.set_yscale('log')
    ax1.legend()

    ax2.plot(epochs, p, label='Robust PPO', color='tab:orange')
    ax2.set_title(title.title())
    ax2.set_xlabel(x_axis.title())
    ax2.set_ylabel(y_axis.title())
    if log:
        ax2.set_yscale('log')
    ax2.legend()

    ax3.plot(epochs, q, label='WocaR-PPO', color='tab:green')
    ax3.set_title(title.title())
    ax3.set_xlabel(x_axis.title())
    ax3.set_ylabel(y_axis.title())
    if log:
        ax3.set_yscale('log')
    ax3.legend()

    # Showing the plot
    plt.tight_layout()
    plt.show()

import matplotlib.pyplot as plt

def plot_together(v, p, q, title, config, x, y):
    epochs=np.arange(len(v))
    # Creating the figure
    fig, ax = plt.subplots(figsize=(8, 6))  # Single plot
    title = f'{title} {config.title()}'
    
    # Plotting data on the same axis
    ax.plot(epochs, v, label='Vanilla', color='tab:blue', linewidth=1.0)
    ax.plot(epochs, p, label='Robust PPO', color='tab:orange', linewidth=1.0)
    ax.plot(epochs, q, label='Robust Q-PPO', color='tab:green', linewidth=1.0)
    
    # Setting title and labels
    ax.set_title(title.title())
    ax.set_xlabel(x.title())
    ax.set_ylabel(y.title())
    
    # Enhancing the plot
    ax.legend()  # Showing the legend to identify each line
    
    # Display the plot
    plt.tight_layout()
    plt.show()


def generate_plots(vanilla_path, ppo_path, q_ppo_path, title, x_axis, y_axis, data_name, config, in_one=False):
    
    v, p, q = get_datasets(vanilla=vanilla_path, robust_ppo=ppo_path, robust_q_ppo=q_ppo_path,  data_name=data_name)
    if in_one:
        plot_together(v, p, q, title, config, x_axis, y_axis)
    else:
        plot(v, p, q, title=title, x_axis=x_axis, y_axis=y_axis, config=config, log=False)

# %% [markdown]
# ## No attacks

# %%
reward_title = 'mean episode reward: Hopper-V4'
reward_x = 'Iteration'
reward_y = 'value'

# %%
vanilla = "/Users/jmuneton/Documents/stanford/s_2024/cs234/project/project/experiments/ vanilla_ppo_hopper/agents_none/exp_20240610_142118/data.h5"
robust_ppo = "/Users/jmuneton/Documents/stanford/s_2024/cs234/project/project/experiments/ robust_ppo_sgld_hopper_best/_none/exp_20240610_204038/data.h5"
robust_q_ppo = "/Users/jmuneton/Documents/stanford/s_2024/cs234/project/project/experiments/ robust_q_ppo_sgld_hopper_best/agents_none/exp_20240610_161030/data.h5"

# %%
loss_title= 'final policy loss'

v_loss, p_loss, q_loss = get_datasets(vanilla, robust_ppo, robust_q_ppo, data_name='mean_std')
plot(v_loss, p_loss, q_loss, title=loss_title, x_axis=reward_x, y_axis='loss', config='no attack', log=False)
# Out:
# entropy_bonus
# final_policy_loss
# final_surrogate_loss
# mean_reward
# mean_std

# %%
plt.plot(v)

# %%
v, p, q = get_datasets(vanilla, robust_ppo, robust_q_ppo, data_name='mean_reward')
plot(v, p, q, title=reward_title, x_axis=reward_x, y_axis=reward_y, config='no attack')
# Out:
# entropy_bonus
# final_policy_loss
# final_surrogate_loss
# mean_reward
# mean_std

# %%
import matplotlib.pyplot as plt

def plot(v, p, q, config):
    epochs=np.arange(len(v))
    # Creating the figure
    fig, ax = plt.subplots(figsize=(8, 6))  # Single plot
    title = f'Mean Episode Reward: Hooper-V4 {config.title()}'
    
    # Plotting data on the same axis
    ax.plot(epochs, v, label='Vanilla', color='tab:blue', linewidth=1.0)
    ax.plot(epochs, q, label='Robust Q-PPO', color='tab:orange', linewidth=1.0)
    ax.plot(epochs, p, label='Robust PPO', color='tab:green', linewidth=1.0)
    
    # Setting title and labels
    ax.set_title(title)
    ax.set_xlabel('Iteration')
    ax.set_ylabel('Reward')
    
    # Enhancing the plot
    ax.legend()  # Showing the legend to identify each line
    
    # Display the plot
    plt.tight_layout()
    plt.show()

# %%
vanilla = '/Users/jmuneton/Documents/stanford/s_2024/cs234/project/project/experiments/ vanilla_ppo_hopper/agents_none/exp_20240601_221955/data.h5'
robust_ppo = "/Users/jmuneton/Documents/stanford/s_2024/cs234/project/project/experiments/ robust_ppo_sgld_hopper_best/_none/exp_20240602_101732/data.h5"
robust_q_ppo = "/Users/jmuneton/Documents/stanford/s_2024/cs234/project/project/experiments/ robust_q_ppo_sgld_hopper_best/agents_none/exp_20240601_231649/data.h5"

# %% [markdown]
# # Random

# %%
vanilla_random = '/Users/jmuneton/Documents/stanford/s_2024/cs234/project/project/experiments/ vanilla_ppo_hopper/agents_random/exp_20240601_222821/data.h5'
robust_ppo_random = "/Users/jmuneton/Documents/stanford/s_2024/cs234/project/project/experiments/ robust_ppo_sgld_hopper_best/_random/exp_20240602_103128/data.h5"
robust_q_ppo_random = "/Users/jmuneton/Documents/stanford/s_2024/cs234/project/project/experiments/ robust_q_ppo_sgld_hopper_best/agents_random/exp_20240601_235252/data.h5"

# %%
v, p, q, = get_datasets(vanilla, robust_ppo, robust_q_ppo, data_name='mean_reward')
# Out:
# entropy_bonus
# final_policy_loss
# final_surrogate_loss
# mean_reward
# mean_std

# %%
vr, pr, qr, epochs = get_datasets(vanilla_random, robust_ppo_random, robust_q_ppo_random)
plot(vr, pr, qr, "random", epochs)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 vr, pr, qr, epochs = get_datasets(vanilla_random, robust_ppo_random, robust_q_ppo_random)
#       2 plot(vr, pr, qr, "random", epochs)
#
# TypeError: get_datasets() missing 1 required positional argument: 'data_name'

# %% [markdown]
# # Critic

# %%
vanilla_critic = '/Users/jmuneton/Documents/stanford/s_2024/cs234/project/project/experiments/ vanilla_ppo_hopper/agents_critic/exp_20240601_223658/data.h5'
robust_ppo_critic = "/Users/jmuneton/Documents/stanford/s_2024/cs234/project/project/experiments/ robust_ppo_sgld_hopper_best/_critic/exp_20240602_110123/data.h5"
robust_q_ppo_critic ="/Users/jmuneton/Documents/stanford/s_2024/cs234/project/project/experiments/ robust_q_ppo_sgld_hopper_best/agents_critic/exp_20240602_012141/data.h5"

# %%
vc, pc, qc, epochs = get_datasets(vanilla_critic, robust_ppo_critic, robust_q_ppo_critic)
plot(vc, pc, qc, "critic", epochs)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 vc, pc, qc, epochs = get_datasets(vanilla_critic, robust_ppo_critic, robust_q_ppo_critic)
#       2 plot(vc, pc, qc, "critic", epochs)
#
# TypeError: get_datasets() missing 1 required positional argument: 'data_name'

# %%
from pptx import Presentation
from pptx.util import Inches

# Create a presentation object
prs = Presentation()

# Define title and content for the slide
title = "Worst-Attack Bellman Operator"
content = """
Instead of explicitly learning the optimal attacker with a large amount of samples, we propose to
directly estimate the worst-case cumulative reward of the policy by characterizing the vulnerability
of the given policy. We first define the worst-attack action value of policy π as Q^π(s, a) := E_p[...]
where the worst-attack value V^π can be defined using h* in the same way, as shown in Definition A.1
in Appendix A. Then, we introduce a novel operator T^π, namely the worst-attack Bellman operator,
defined as below.

Definition 4.1 (Worst-attack Bellman Operator):
For MDP M, given a fixed policy π and attack radius ε, define the worst-attack Bellman operator T^π as
T^πQ(s, a) := E_s'[P(s, a)][R(s, a) + γ min_a'∈A_adv(s', π) Q(s', a')]

where ∀s ∈ S, A_adv(s, π) is defined as
A_adv(s, π) := {a ∈ A : ∃s ∈ B_ε(s) s.t. π(s) = a}.

Here A_adv(s', π) denotes the set of actions an adversary can mislead the victim π into selecting by
perturbing the state s' into a neighboring state s ∈ B_ε(s'). This hypothetical perturbation to the
future state s' is the key for characterizing the worst-case long-term reward under attack. The following
theorem associates the worst-attack Bellman operator and the worst-attack action value.
"""

# Add a slide with title and content layout
slide_layout = prs.slide_layouts[1]  # 0 is title slide, 1 is title and content
slide = prs.slides.add_slide(slide_layout)

# Add title and content to the slide
title_placeholder = slide.shapes.title
title_placeholder.text = title

content_placeholder = slide.placeholders[1]
content_placeholder.text = content

# Save the presentation
file_path = "./Worst_Attack_Bellman_Operator_Slide.pptx"
prs.save(file_path)

file_path
# Out:
# './Worst_Attack_Bellman_Operator_Slide.pptx'

# %%
ppo_random = "/Users/jmuneton/Documents/stanford/s_2024/cs234/project/project/experiments/ robust_ppo_sgld_hopper_best/_random/exp_20240603_054906/data.h5"
q_ppo_random = "/Users/jmuneton/Documents/stanford/s_2024/cs234/project/project/experiments/ robust_q_ppo_sgld_hopper_best/agents_random/exp_20240603_021441/data.h5"
vanilla_random = "/Users/jmuneton/Documents/stanford/s_2024/cs234/project/project/experiments/ vanilla_ppo_hopper/agents_random/exp_20240603_081542/data.h5"
title = 'mean episode reward: Hopper-V4'
config = 'random attack'
x = 'iteration'
y = 'reward'
data_name = 'mean_reward'
generate_plots(vanilla_path=vanilla_random,
               ppo_path=ppo_random,
               q_ppo_path=q_ppo_random,
               title=title,
               x_axis=x,
               y_axis=y,
               data_name=data_name,
               config=config
               )
# Out:
# entropy_bonus
# final_policy_loss
# final_surrogate_loss
# mean_reward
# mean_std
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[36], line 9
#       7 y = 'reward'
#       8 data_name = 'mean_reward'
# ----> 9 generate_plots(vanilla_path=vanilla_random,
#      10                ppo_path=ppo_random,
#      11                q_ppo_path=q_ppo_random,
#      12                title=title,
#      13                x_axis=x,
#      14                y_axis=y,
#      15                data_name=data_name,
#      16                config=config
#      17                )
#
# Cell In[22], line 67, in generate_plots(vanilla_path, ppo_path, q_ppo_path, title, x_axis, y_axis, data_name, config, in_one)
#      65     plot_together(v, p, q, title, config, x_axis, y_axis)
#      66 else:
# ...

# %%
ppo_random = "/Users/jmuneton/Documents/stanford/s_2024/cs234/project/project/experiments/ robust_ppo_sgld_hopper_best/_random/exp_20240603_054906/data.h5"
q_ppo_random = "/Users/jmuneton/Documents/stanford/s_2024/cs234/project/project/experiments/ robust_q_ppo_sgld_hopper_best/agents_random/exp_20240603_021441/data.h5"
vanilla_random = "/Users/jmuneton/Documents/stanford/s_2024/cs234/project/project/experiments/ vanilla_ppo_hopper/agents_random/exp_20240603_081542/data.h5"
title = 'mean std: Hopper-V4'
config = 'random attack'
x = 'iteration'
y = 'std'
data_name = 'mean_std'
generate_plots(vanilla_path=vanilla_random,
               ppo_path=ppo_random,
               q_ppo_path=q_ppo_random,
               title=title,
               x_axis=x,
               y_axis=y,
               data_name=data_name,
               config=config, 
               in_one=True
               )
# Out:
# entropy_bonus
# final_policy_loss
# final_surrogate_loss
# mean_reward
# mean_std

# %%
ppo_critic = "/Users/jmuneton/Documents/stanford/s_2024/cs234/project/project/experiments/ robust_ppo_sgld_hopper_best/_critic/exp_20240603_061537/data.h5"
q_ppo_critic = "/Users/jmuneton/Documents/stanford/s_2024/cs234/project/project/experiments/ robust_q_ppo_sgld_hopper_best/agents_critic/exp_20240603_032036/data.h5"
vanilla_critic = "/Users/jmuneton/Documents/stanford/s_2024/cs234/project/project/experiments/ vanilla_ppo_hopper/agents_critic/exp_20240603_083114/data.h5"
title = 'mean episode reward: Hopper-V4'
config = 'critic attack'
x = 'iteration'
y = 'reward'
data_name = 'mean_reward'
generate_plots(vanilla_path=vanilla_critic,
               ppo_path=ppo_critic,
               q_ppo_path=q_ppo_critic,
               title=title,
               x_axis=x,
               y_axis=y,
               data_name=data_name,
               config=config
               )
# Out:
# entropy_bonus
# final_policy_loss
# final_surrogate_loss
# mean_reward
# mean_std
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[38], line 9
#       7 y = 'reward'
#       8 data_name = 'mean_reward'
# ----> 9 generate_plots(vanilla_path=vanilla_critic,
#      10                ppo_path=ppo_critic,
#      11                q_ppo_path=q_ppo_critic,
#      12                title=title,
#      13                x_axis=x,
#      14                y_axis=y,
#      15                data_name=data_name,
#      16                config=config
#      17                )
#
# Cell In[22], line 67, in generate_plots(vanilla_path, ppo_path, q_ppo_path, title, x_axis, y_axis, data_name, config, in_one)
#      65     plot_together(v, p, q, title, config, x_axis, y_axis)
#      66 else:
# ...

# %%
ppo_critic = "/Users/jmuneton/Documents/stanford/s_2024/cs234/project/project/experiments/ robust_ppo_sgld_hopper_best/_critic/exp_20240603_061537/data.h5"
q_ppo_critic = "/Users/jmuneton/Documents/stanford/s_2024/cs234/project/project/experiments/ robust_q_ppo_sgld_hopper_best/agents_critic/exp_20240603_032036/data.h5"
vanilla_critic = "/Users/jmuneton/Documents/stanford/s_2024/cs234/project/project/experiments/ vanilla_ppo_hopper/agents_critic/exp_20240603_083114/data.h5"
title = 'Entropy Bonus: Hopper-V4'
config = 'random attack'
x = 'iteration'
y = 'Entropy'
data_name = 'entropy_bonus'
generate_plots(vanilla_path=vanilla_random,
               ppo_path=ppo_random,
               q_ppo_path=q_ppo_random,
               title=title,
               x_axis=x,
               y_axis=y,
               data_name=data_name,
               config=config,
               in_one=True
               )
# Out:
# entropy_bonus
# final_policy_loss
# final_surrogate_loss
# mean_reward
# mean_std

# %%
vanilla ="/Users/jmuneton/Documents/stanford/s_2024/cs234/project/project/experiments/ vanilla_ppo_hopper/agents_none/exp_20240610_090232/data.h5"
robust_ppo = "/Users/jmuneton/Documents/stanford/s_2024/cs234/project/project/experiments/ robust_ppo_sgld_hopper_best/_none/exp_20240603_052241/data.h5"
robust_q_ppo = "/Users/jmuneton/Documents/stanford/s_2024/cs234/project/project/experiments/ robust_q_ppo_sgld_hopper_best/agents_none/exp_20240603_010842/data.h5"

title = 'mean episode reward: Hopper-V4'
config = 'none'
x = 'iteration'
y = 'reward'
data_name = 'mean_reward'
generate_plots(vanilla_path=vanilla,
               ppo_path=robust_ppo,
               q_ppo_path=robust_q_ppo,
               title=title,
               x_axis=x,
               y_axis=y,
               data_name=data_name,
               config=config
               )
# Out:
# entropy_bonus
# final_policy_loss
# final_surrogate_loss
# mean_reward
# mean_std
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[54], line 10
#       8 y = 'reward'
#       9 data_name = 'mean_reward'
# ---> 10 generate_plots(vanilla_path=vanilla,
#      11                ppo_path=robust_ppo,
#      12                q_ppo_path=robust_q_ppo,
#      13                title=title,
#      14                x_axis=x,
#      15                y_axis=y,
#      16                data_name=data_name,
#      17                config=config
#      18                )
#
# Cell In[22], line 67, in generate_plots(vanilla_path, ppo_path, q_ppo_path, title, x_axis, y_axis, data_name, config, in_one)
#      65     plot_together(v, p, q, title, config, x_axis, y_axis)
#      66 else:
# ---> 67     plot(v, p, q, title=title, x_axis=x_axis, y_axis=y_axis, config=config, log=False)
#
# ...

# %%
mv, mp, mq = get_datasets(vanilla, robust_ppo ,robust_q_ppo, data_name='mean_reward')
# Out:
# entropy_bonus
# final_policy_loss
# final_surrogate_loss
# mean_reward
# mean_std

# %%
mv, mp, mq = np.mean(mv[-100:]), np.mean(mp[-100:]), np.mean(mq[-100:])

# %%
print(mv, mp, mq)
# Out:
# 2031.7886033024724 1540.4426703680424 2493.916485523663

# %%
a = [1,2,3,4,5,6]

# %%
a[-3:]
# Out:
# [4, 5, 6]
